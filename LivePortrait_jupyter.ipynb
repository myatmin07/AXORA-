# %% [markdown]
# <a href="https://colab.research.google.com/github/myatmin07/AXORA-/blob/main/LivePortrait_jupyter.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# %cd /content
# !git clone -b dev https://github.com/camenduru/LivePortrait
# %cd /content/LivePortrait

# !rm -rf /content/LivePortrait/pretrained_weights
# !git clone https://huggingface.co/camenduru/LivePortrait /content/LivePortrait/pretrained_weights

# !pip install tyro==0.8.5 onnxruntime-gpu onnx gradio==4.36.1 colorama


# %cd /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython
# !python setup.py build_ext --inplace
# Out:
# /content
# fatal: destination path 'LivePortrait' already exists and is not an empty directory.
# /content/LivePortrait
# Cloning into '/content/LivePortrait/pretrained_weights'...
# remote: Enumerating objects: 19, done.
# remote: Total 19 (delta 0), reused 0 (delta 0), pack-reused 19 (from 1)
# Receiving objects: 100% (19/19), done.
# Requirement already satisfied: tyro==0.8.5 in /usr/local/lib/python3.13/dist-packages (0.8.5)
# Requirement already satisfied: onnxruntime-gpu in /usr/local/lib/python3.13/dist-packages (1.30.0)
# Requirement already satisfied: onnx in /usr/local/lib/python3.13/dist-packages (1.22.0)
# Requirement already satisfied: gradio==4.36.1 in /usr/local/lib/python3.13/dist-packages (4.36.1)
# Requirement already satisfied: colorama in /usr/local/lib/python3.13/dist-packages (0.4.6)
# Requirement already satisfied: docstring-parser>=0.16 in /usr/local/lib/python3.13/dist-packages (from tyro==0.8.5) (0.18.0)
# Requirement already satisfied: typing-extensions>=4.7.0 in /usr/local/lib/python3.13/dist-packages (from tyro==0.8.5) (4.16.0)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.13/dist-packages (from tyro==0.8.5) (13.9.4)
# Requirement already satisfied: shtab>=1.5.6 in /usr/local/lib/python3.13/dist-packages (from tyro==0.8.5) (1.12.1)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (23.2.1)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (5.5.0)
# Requirement already satisfied: fastapi in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (0.141.1)
# Requirement already satisfied: ffmpy in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (1.0.0)
# Requirement already satisfied: gradio-client==1.0.1 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (1.0.1)
# Requirement already satisfied: httpx>=0.24.1 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (0.28.1)
# Requirement already satisfied: huggingface-hub>=0.19.3 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (1.29.0)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (6.5.2)
# Requirement already satisfied: jinja2<4.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (3.1.6)
# Requirement already satisfied: markupsafe~=2.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (2.1.5)
# Requirement already satisfied: matplotlib~=3.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (3.10.0)
# Requirement already satisfied: numpy<3.0,>=1.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (2.1.3)
# Requirement already satisfied: orjson~=3.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (3.12.0)
# Requirement already satisfied: packaging in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (26.3)
# Requirement already satisfied: pandas<3.0,>=1.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (2.2.3)
# Requirement already satisfied: pillow<11.0,>=8.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (10.4.0)
# Requirement already satisfied: pydantic>=2.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (2.13.5)
# Requirement already satisfied: pydub in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (0.25.1)
# Requirement already satisfied: python-multipart>=0.0.9 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (0.0.32)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (6.0.3)
# Requirement already satisfied: ruff>=0.2.2 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (0.16.7)
# Requirement already satisfied: semantic-version~=2.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (2.10.0)
# Requirement already satisfied: tomlkit==0.12.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (0.12.0)
# Requirement already satisfied: typer<1.0,>=0.12 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (0.27.2)
# Requirement already satisfied: urllib3~=2.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (2.5.0)
# Requirement already satisfied: uvicorn>=0.14.0 in /usr/local/lib/python3.13/dist-packages (from gradio==4.36.1) (0.52.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.13/dist-packages (from gradio-client==1.0.1->gradio==4.36.1) (2025.12.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /usr/local/lib/python3.13/dist-packages (from gradio-client==1.0.1->gradio==4.36.1) (11.0.3)
# Requirement already satisfied: flatbuffers in /usr/local/lib/python3.13/dist-packages (from onnxruntime-gpu) (25.12.19)
# Requirement already satisfied: protobuf>=4.25.8 in /usr/local/lib/python3.13/dist-packages (from onnxruntime-gpu) (5.29.6)
# Requirement already satisfied: ml_dtypes>=0.5.4 in /usr/local/lib/python3.13/dist-packages (from onnx) (0.6.0)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.13/dist-packages (from altair<6.0,>=4.2.0->gradio==4.36.1) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.13/dist-packages (from altair<6.0,>=4.2.0->gradio==4.36.1) (2.25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.13/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (4.14.2)
# Requirement already satisfied: certifi in /usr/local/lib/python3.13/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (2026.7.22)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.13/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.13/dist-packages (from httpx>=0.24.1->gradio==4.36.1) (3.19)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.13/dist-packages (from httpcore==1.*->httpx>=0.24.1->gradio==4.36.1) (0.16.0)
# Requirement already satisfied: click<9.0.0,>=8.4.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (8.5.0)
# Requirement already satisfied: filelock>=3.10.0 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (3.32.5)
# Requirement already satisfied: hf-xet<2.0.0,>=1.5.2 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (1.6.0)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.13/dist-packages (from huggingface-hub>=0.19.3->gradio==4.36.1) (4.67.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (1.5.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (3.3.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.13/dist-packages (from matplotlib~=3.0->gradio==4.36.1) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas<3.0,>=1.0->gradio==4.36.1) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas<3.0,>=1.0->gradio==4.36.1) (2026.3)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->gradio==4.36.1) (0.8.0)
# Requirement already satisfied: pydantic-core==2.46.5 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->gradio==4.36.1) (2.46.5)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.13/dist-packages (from pydantic>=2.0->gradio==4.36.1) (0.4.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.13/dist-packages (from rich>=11.1.0->tyro==0.8.5) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.13/dist-packages (from rich>=11.1.0->tyro==0.8.5) (2.21.0)
# Requirement already satisfied: shellingham>=1.3.0 in /usr/local/lib/python3.13/dist-packages (from typer<1.0,>=0.12->gradio==4.36.1) (1.5.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.13/dist-packages (from typer<1.0,>=0.12->gradio==4.36.1) (0.0.5)
# Requirement already satisfied: starlette>=0.46.0 in /usr/local/lib/python3.13/dist-packages (from fastapi->gradio==4.36.1) (1.6.0)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio==4.36.1) (2026.6.3)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.13/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro==0.8.5) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio==4.36.1) (1.17.0)
# /content/LivePortrait/src/utils/dependencies/insightface/thirdparty/face3d/mesh/cython

# %%
# %cd /content/LivePortrait
# !python inference.py -s /content/LivePortrait/assets/examples/source/s7.jpg -d /content/LivePortrait/assets/examples/driving/d7.mp4
# Out:
# /content/LivePortrait
# Traceback (most recent call last):
#   File "/content/LivePortrait/inference.py", line 33, in <module>
#     main()
#     ~~~~^^
#   File "/content/LivePortrait/inference.py", line 23, in main
#     live_portrait_pipeline = LivePortraitPipeline(
#         inference_cfg=inference_cfg,
#         crop_cfg=crop_cfg
#     )
#   File "/content/LivePortrait/src/live_portrait_pipeline.py", line 38, in __init__
#     self.live_portrait_wrapper: LivePortraitWrapper = LivePortraitWrapper(cfg=inference_cfg)
#                                                       ~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^
#   File "/content/LivePortrait/src/live_portrait_wrapper.py", line 29, in __init__
#     self.appearance_feature_extractor = load_model(cfg.checkpoint_F, model_config, cfg.device_id, 'appearance_feature_extractor')
#                                         ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/content/LivePortrait/src/utils/helper.py", line 134, in load_model
#     model.load_state_dict(torch.load(ckpt_path, map_location=lambda storage, loc: storage))
#                           ~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.13/dist-packages/torch/serialization.py", line 1602, in load
#     raise pickle.UnpicklingError(_get_wo_message(str(e))) from None
# _pickle.UnpicklingError: Weights only load failed. In PyTorch 2.6, we changed the default value of the `weights_only` argument in `torch.load` from `False` to `True`. Re-running `torch.load` with `weights_only` set to `False` will likely succeed, but it can result in arbitrary code execution. Do it only if you got the file from a trusted source.
# Please file an issue with the following so that we can make `weights_only=True` compatible with your use case: WeightsUnpickler error:
#
# Unsupported operand 118
#
# Check the documentation of torch.load to learn more about types accepted by default with weights_only https://pytorch.org/docs/stable/generated/torch.load.html.
